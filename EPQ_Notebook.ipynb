# %% [markdown]
# <a href="https://colab.research.google.com/github/VedGandhe/EPQ/blob/main/EPQ_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.parse import urljoin, urlparse

def get_wikipedia_article_links(url):
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = bs(response.text, 'html.parser')
        links = []
        exclude = ['/wiki/Special:', '/wiki/Help:', '/wiki/Template:', '/wiki/Talk:', '/wiki/Category:', '/wiki/File:']
        for a in soup.find_all('a', href=True):
            href = a['href']
            if href.startswith('/wiki/') and not any(href.startswith(prefix) for prefix in exclude):
                full_url = urljoin(url, href)
                links.append(full_url)
        return set(links)

    except Exception as f:
        print(f"An error occurred: {f}")
        return []

if __name__ == "__main__":
    wikipedia_url = input("Enter the URL of the Wikipedia page: ")
    links = get_wikipedia_article_links(wikipedia_url)
    print("Extracted Wikipedia Article Links:")
    print(len(links))
    for link in links:
        print(link)
# Out:
# Enter the URL of the Wikipedia page: https://en.wikipedia.org/wiki/Graph_theory
# Extracted Wikipedia Article Links:
# 488
# https://en.wikipedia.org/wiki/Group_theory
# https://en.wikipedia.org/wiki/List_of_computer_size_categories
# https://en.wikipedia.org/wiki/Gustav_Kirchhoff
# https://en.wikipedia.org/wiki/Decision_support_system
# https://en.wikipedia.org/wiki/Camille_Jordan
# https://en.wikipedia.org/wiki/Interaction_design
# https://en.wikipedia.org/wiki/Geometric_topology
# https://en.wikipedia.org/wiki/Template_talk:Areas_of_mathematics
# https://en.wikipedia.org/wiki/Universal_algebra
# https://en.wikipedia.org/wiki/Genomics
# https://en.wikipedia.org/wiki/Peter_Tait_(physicist)
# https://en.wikipedia.org/wiki/Enterprise_information_system
# https://en.wikipedia.org/wiki/Gottfried_Wilhelm_Leibniz
# https://en.wikipedia.org/wiki/Connectomics
# https://en.wikipedia.org/wiki/Mathematical_sociology
# https://en.wikipedia.org/wiki/Condensed_matter_physics
# ...
